# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ICT110
# Out:
# /content/drive/MyDrive/ICT110

# %%
file = open('line.txt')

print("'line.txt' before getting upper case")
for line in file:
    line = line.rstrip()
    print(line)


print("\n'line.txt' after getting upper case")
file = open('line.txt')
for line1 in file:
    line1 = line1.rstrip()
    line1 = line1.upper()
    print(line1)
# Out:
# 'line.txt' before getting upper case
# justine fritz flores
# bachelor of science in computer science
# iloilo science and technology university
#
# 'line.txt' after getting upper case
# JUSTINE FRITZ FLORES
# BACHELOR OF SCIENCE IN COMPUTER SCIENCE
# ILOILO SCIENCE AND TECHNOLOGY UNIVERSITY

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
line_count = int()
f = open('line.txt')

for line in f:
  line = line.rstrip()
  print(line)
  line_count += 1
print(f"\nTotal of lines : {line_count}")
# Out:
# justine fritz flores
# bachelor of science in computer science
# iloilo science and technology university
#
# Total of lines : 3

# %% [markdown]
# ## CHALLENGE
#
# from [PEW] E8-2

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %%
total_confidence = float()
count = int()

file_name = input("Enter the file name : ")

try:
  file = open(file_name)
  for line in file:
    if line.startswith('X-DSPAM-Confidence:'):
        confidence = float(line.split(':')[1].strip())
        total_confidence += confidence
        count += 1


  if count > 0:
    average_confidence = total_confidence / count
    print(f"The X-DSPAM-Confidence is : {average_confidence}")
  else:
    print(f"{file_name} doesn't contains X-DSPAM-Confidence..")
except:
  print(f"{file_name} doesn't exist..")
# Out:
# Enter the file name : mbox-short.txt
# The X-DSPAM-Confidence is : 0.8941280467445736
