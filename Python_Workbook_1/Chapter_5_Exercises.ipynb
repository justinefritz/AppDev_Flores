# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
a = 2
b = 2.0
c = a

#b and a also b and c has a same value even though their data types is different
# using '==' is for value equality. Use it when you would like to know if two objects have the same value.
if b == a:
  print('b == a?', a, b,)
if b == c:
  print('b == c?', b, c)

#c and a has same value and data type.
# using 'is' for reference equality. Use it when you would like to know if two references refer to the same object.
if c is a:
  print('c is a?', c, a)


# c and a has same value, but canoot refer as a same object because b is an float and a is an integer, vice versa to b and c
# so we can conclude that the statement below will not execute
if b is a:
  print('b is a?', b, a)
if b is c:
  print('b is c?', b, c)
# Out:
# b == a? 2 2.0
# b == c? 2.0 2
# c is a? 2 2

# %% [markdown]
# ## CHALLENGES

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0
index = False

while True :
  typein = input('Enter a number: ')
  if (typein == 'done'):
    break
  else:
    try:
      num = int(typein)
      total = total + num
      count = count + 1
      index = True
    except:
      print('Invalid input')

if index:
  print(total, count, total/count)
# Out:
# Enter a number: 4
# Enter a number: r
# Invalid input
# Enter a number: 5
# Enter a number: 23
# Enter a number: done
# 32 3 10.666666666666666

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
max = 0
min = 0
index = False
i = 1

while True :
  typein = input('Enter a number: ')
  if (typein == 'done'):
    break
  else:
    try:
      num = int(typein)
      index = True
      if index and i == 1:
        max = num
        min = num

      if num > max:
        max = num
      if num < min:
        min = num

      i = 2
    except:
      print('Invalid input')

print(min, max)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: done
# 4 5
