# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an **error**. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!') #The code has a syntax error due to letter p in print is big letter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ed98d0a0a2c8> in <cell line: 1>()
# ----> 1 Print('Hello world!') #The code has a syntax error due to letter p in print is big letter
#
# NameError: name 'Print' is not defined

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print'Hello world!') #The code has a syntax error due to lack of left side (

# %%
print('Hello world!')

# %%
print('Hello world!)
#The code has a syntax error due to last of right side '

# %%
print('Hello world!')

# %%
print('Hello world!'')
#The code has a syntax due double '' in right side '

# %%
print('Hello world!')

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)

#x = 43 and 43 = 43 + 1 = 44, so the new value of x is 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)

#The code has a syntax due to attribute X must be small letter

# %%
x = 43
x = x + 1
print(x)
